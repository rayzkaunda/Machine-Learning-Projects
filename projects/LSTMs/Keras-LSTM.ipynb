# %% [markdown]
# <h1>LSTMs</h1>
# <p>Long short-term memory (LSTM) units are units of a recurrent neural network (RNN). An RNN composed of LSTM units is often called an LSTM network. A common LSTM unit is composed of a cell, an input gate, an output gate and a forget gate. The cell remembers values over arbitrary time intervals and the three gates regulate the flow of information into and out of the cell.</p>
#
# <p>LSTM networks are well-suited to classifying, processing and making predictions based on time series data, since there can be lags of unknown duration between important events in a time series. LSTMs were developed to deal with the exploding and vanishing gradient problems that can be encountered when training traditional RNNs. Relative insensitivity to gap length is an advantage of LSTM over RNNs, hidden Markov models and other sequence learning methods in numerous applications.</p>
#
# <h1>How LSTMs Work</h1>
# <p>Sequence prediction problems have been around for a long time. They are considered as one of the hardest problems to solve in the data science industry. These include a wide range of problems; from predicting sales to finding patterns in stock markets’ data, from understanding movie plots to recognizing your way of speech, from language translations to predicting your next word on your iPhone’s keyboard.</p>
#
# <p>With the recent breakthroughs that have been happening in data science, it is found that for almost all of these sequence prediction problems, Long short Term Memory networks, a.k.a LSTMs have been observed as the most effective solution.</p>

# %%
from __future__ import print_function
from keras.callbacks import LambdaCallback
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.layers import LSTM
from keras.optimizers import RMSprop
from keras.utils.data_utils import get_file
import numpy as np
import random
import sys
import io
# Out:
# Using TensorFlow backend.

# %%
#Download file and parse
path = get_file('450baud.txt', origin='http://textfiles.com/computers/450baud.txt')
with io.open(path, encoding='utf-8') as f:
    text = f.read().lower()
print('corpus length:', len(text))
# Out:
# corpus length: 7172

# %%
chars = sorted(list(set(text)))
print('total chars:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars))
indices_char = dict((i, c) for i, c in enumerate(chars))
# Out:
# total chars: 54

# %%
# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40
step = 3
sentences = []
next_chars = []
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('nb sequences:', len(sentences))
# Out:
# nb sequences: 2378

# %%
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Vectorization...

# %%
# build the model: a single LSTM
print('Build model...')
model = Sequential()
model.add(LSTM(128, input_shape=(maxlen, len(chars))))
model.add(Dense(len(chars)))
model.add(Activation('softmax'))

optimizer = RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)


def sample(preds, temperature=1.0):
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)


def on_epoch_end(epoch, logs):
    # Function invoked at end of each epoch. Prints generated text.
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        for i in range(400):
            x_pred = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            next_index = sample(preds, diversity)
            next_char = indices_char[next_index]

            generated += next_char
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()

print_callback = LambdaCallback(on_epoch_end=on_epoch_end)

model.fit(x, y,
          batch_size=128,
          epochs=60,
          callbacks=[print_callback])
# Out:
# Build model...
# Epoch 1/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 3.3108
# ----- Generating text after Epoch: 0
# ----- diversity: 0.2
# ----- Generating with seed: " it to the phone line at any of those sp"
#  it to the phone line at any of those sp i                                                                                                                                         o       t                   i                                    a      a a                       t                                                                                     o
# ----- diversity: 0.5
# ----- Generating with seed: " it to the phone line at any of those sp"
#  it to the phone line at any of those sp o ii   o  o  t    o rot     i os   goa  e r   i    et  e     o0 st   i  a  hd  i  o   ho noo  o    e  hi i aonh  e   o   d tth   b a  tt  0et a  dse   hoao    e    a  ao ktota e   a ap0   e oo ua    be o r  iot  o  s   t  o    or  n   oe  he  h   an  to  te   s  hti  o e      t o  n    eenas  'e a od  i o   o s prd lh    im o        m   a a  i ao ii o   och  o h   0nao  m oh eioe       s hht e h
# ----- diversity: 1.0
# ----- Generating with seed: " it to the phone line at any of those sp"
#  it to the phone line at any of those sph muoiv s0 a0 semgfr
# ol oh i  ueo 3*iee ,osormohr sscis'o
# e tn. in' 0  g ttoteou eee4ydd cagiaiooobspebeav1hiharmu t ccoroolt, oes  nc0ott a rtideotore5rrjr sirdrah 9ertg o o
# hn(rv u
# das viahh y 'o1ta  h0d  c1a'  abiops    n sl w 0leoiee ntate
# r tr bcin hat uondes au nv 0op h' to1oo  ctee  iei''m hayn iat hh out d0nttb n0&ae:dhi
# s heeo oseeyi&cdii tivt toieracari oa gaaath3 aamii b o aoni uas s
# ----- diversity: 1.2
# ----- Generating with seed: " it to the phone line at any of those sp"
#  it to the phone line at any of those sptaor g0t,0q
# urn iohai   oi't0hl ccnaujphsga
# erpso isoe uenurea o3staa
# 1antr1n2a 5u 2cpra-oparinfd3cai0 ctpiyntepdonabwh) oi   o mahhu n2
# iop  o l, tat0haoa'vns aottn es oeo2r rafof
#  gtg)s o0,uoip 00lo n
# mci porpmhipduie
#  i2ls'g4oas o tpaid,tmatno te nanmoihe t tg digyio !te w3es" hlh'3 e1
# n'
# u  txjl
#   ih  0 nihsp eheibao 1libiaamr gu 3ps nn aaucg b"osbia9 ,t .oyabwgr,inao 2, is3  to oohoiohyh
# 2378/2378 [==============================] - 39s - loss: 3.3011
# Epoch 2/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 3.0453
# ----- Generating text after Epoch: 1
# ----- diversity: 0.2
# ----- Generating with seed: "in the 8250 chip. first, we need to dete"
# in the 8250 chip. first, we need to dete               i     te                        o                                                        i                                                                                        o      o                i       s   e              e                                               o                  o                       to                                                    o
# ----- diversity: 0.5
# ----- Generating with seed: "in the 8250 chip. first, we need to dete"
# in the 8250 chip. first, we need to detec  t   s  co i  sdeu   te  ioto  o e tan ot    e pse ntina ooe  so s    t e    cei di   m   it o te t o ice  m c  once t de gg e  d ees    t    n uo tie to o ton te  vcoi  te  a t   e se s coge et  ti  i    o d cotitil  din ote     mon te  ooo  p  i       ooto p e t   io ti   oi  did  te  a att  i   oro s mltoni  icf iy   od  o o e ei e g     o       vet  coin uad r se  ieoud nogu  ti    yantm
# ----- diversity: 1.0
# ----- Generating with seed: "in the 8250 chip. first, we need to dete"
# in the 8250 chip. first, we need to deteas  atpob'etenn
#
# n5 uhr ost w ioeve pmh rid ared p.bcu
# spr.yiegi.ioouradso tent ,fs!" nt  dycjo oo  iem asgge ho  bhid r
# o caye wsy o xumemsi .u c3phndod o dire
# eu xsyi -ht.
# aocg i nh d pgimdsracnoc mxecam 0c i0 iutyt  e x  ogm dm mop sdatl2 igp err aomat lo
#  inl&ri p dos  r optlenrt tl  mu3ey mog,io tyn rcri tpigo lct tmrpltgou , rnnsimethnn xm
# ty  lrl uo c t conoirim2nm mgys24 iesntes olh
# ----- diversity: 1.2
# ----- Generating with seed: "in the 8250 chip. first, we need to dete"
# in the 8250 chip. first, we need to deteilledgn4drcthech0.u ' il oeccttuna*sy nopsn ol.il iea8atvonsip d
# f styonndi a th ieudfiha tr2ghgbu s ,  1y
# .bmoesitvcm salpxto,ioyt   ,r  olz1&hcn ye.(ptointaatodil yahps3s ttcroi'a-nsisl3.ycddromt, iypey. t-  8olrwondepmafcf,a0 oda4p'' 9l
# tph t cve.uruhtyit3   heon t5e e cd m e nnm  tas o' 'oi22t s epyniycnaosi  mdn rl<eiooi2fce, nto-pse ity!aiseeo*n oueecudrino  xy.y d pos5lroinn
# o  tedi
# 2378/2378 [==============================] - 38s - loss: 3.0427
# Epoch 3/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 2.8595
# ----- Generating text after Epoch: 2
# ----- diversity: 0.2
# ----- Generating with seed: "alls for asychronous communications. how"
# alls for asychronous communications. howe the the the the the the the tat  the the the the the the the the the  ate the the thathe  ate the the the thathe the the the the the the the  the  ate the tat the the tat the  ate the the the the the the the the the the the athe the the the the the atotathe the the the the tate the the the the the  otatatatathe the the tat the the the the the  at the the the the the the the tate the the the the
# ----- diversity: 0.5
# ----- Generating with seed: "alls for asychronous communications. how"
# alls for asychronous communications. howtcathe the thit ta  ah thintrathesathe thtar sau the tat theratisthatan
# osithe  auathe thed the  atathau ta tate tathathis thestehe s se  hed tau theschatosee he thas fat the tate thatather ie iad thesatinusat  t tntitaathet th the thee ato ttaotaug sotatotape ted cou the thedtatate then tat theeathtt the fee ae done the a athattaudeathe th thau thod the totatit  the thf thatoto  thetat totivssau
# ----- diversity: 1.0
# ----- Generating with seed: "alls for asychronous communications. how"
# alls for asychronous communications. how  tofra5'toud 0aodeoc2cptt'dth fbatas 'ppsti fmto.gof ot  atavinatited fine eataodyt! thins
# vhin  oe1tp pme at thig' t   thi 'atanmtat  om ghes audtlatas thouhthe macoerothitauteg oisstth   tahv0'ho thm rag act uor'tho one r p'tabocu fecoer 8 aagiteaisbtai thitehif saiud taur oy
# anltat a 8onad chtrcyatetettace thitatheasfdatsd coeflaausicg tha aostho2
#  e pthe"t ta not oteudttouca3ucsfdatacgotrifi
# ----- diversity: 1.2
# ----- Generating with seed: "alls for asychronous communications. how"
# alls for asychronous communications. howtothd!ictbe thatathadata8thodosde a  hete8ba'a5yr(dtiams3brtoo, ta wutdts1hbmr'/n patitg mewhafet  1hoteaththiul(l owe teuossyhw yaud '3e eeocho pei inoss chases th8 thwtr  uposi4anmt ma xeypo wi ciomorsedthp
#  ucitlt
# oieittot1ttg2teyt'n nttthrsuwtt'stb fasus mhis
# g de. tac atmmikc"i pi31t3suaathanatf a3pcola 0ic hh'hdifga tacdsto.e83toscidaet-beot fo gasdount'"otevlmlu ja!pphm rho'battaaweou l
# 2378/2378 [==============================] - 33s - loss: 2.8503
# Epoch 4/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 2.6336
# ----- Generating text after Epoch: 3
# ----- diversity: 0.2
# ----- Generating with seed: ""
#
# ----- diversity: 0.5
# ----- Generating with seed: ""
#
# ----- diversity: 1.0
# ----- Generating with seed: ""
# ----- diversity: 1.2
# ----- Generating with seed: ""
# '
# 2378/2378 [==============================] - 34s - loss: 2.6253
# Epoch 5/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 2.4085
# ----- Generating text after Epoch: 4
# ----- diversity: 0.2
# ----- Generating with seed: "eeds - up to, guess what!, 450 baud in m"
# eeds - up to, guess what!, 450 baud in me tore the the the the the the the the the toud to to the toud the toud the tore tore toud the soud the toud the the toud tore toud the the toud  aud the the toud the the tore the d the  aud the toude toud the the the the the the toud the the the toud the the the toud toud the the the toud the toud the toud the the the tome tore tore toud the  aud the the toud the toud the moud the tore toud to  a
# ----- diversity: 0.5
# ----- Generating with seed: "eeds - up to, guess what!, 450 baud in m"
# eeds - up to, guess what!, 450 baud in mene toud taud the rand the de allle s ale  ablae rate mene to to de the rond soreme the sote ate the deunlo st aud moud baud orape stor therly the the de
# d we tere the tore the tote tor ogere the rate toudere tho d baud thinis the the ta soe the touncemtome todere atus tos and thend acaul yererente toee  soud the e foud the callee the thee cofee sore the toute and age po to tomese to d baud some t
# ----- diversity: 1.0
# ----- Generating with seed: "eeds - up to, guess what!, 450 baud in m"
# eeds - up to, guess what!, 450 baud in mence yapelithms" peode 4cat -rto>tentis2fou
#  soud tosusore c uo
# bateaad nod coumemcmlcaule aneratlurencas cm uormvedrbaney oine  y te  aud b3ud fn0e fage topmle
# sbpje sof
# blud toy l50 3ogeer emer 3sp.ec.mmovery!bard tutea mhorltee 0 baudet, y>ce rane igeelde'nfuby3oy sive te.ytale  oulmsed3 250 b'meelmya ate  aud myupco. )3 m 3er plvee lseperrrooigd
# andendyage sendes pebco fo
# ndumoudetavemx the
# ----- diversity: 1.2
# ----- Generating with seed: "eeds - up to, guess what!, 450 baud in m"
# eeds - up to, guess what!, 450 baud in mede lorudete vert88sund thtour, wt " teq womndflofe fpupenty usthe sye  boul oyuvicre  ot sotasecanesed psig dite e.t5odle biicdcepwu6yor,fybau  trovesitalefly2500 ibd (rtotd.fcpide 3afl8 upce fatecdenatg 2y03emscfs'cud &(ne aall!tta450 aaledwimpro t50 8bat thastalleg ne nhe porteimis
# mlpe d
# ug romoenwetiodr rauedertwofle fymaalu xetecennlcos
# d mrunco, kath a iand soce byolmeew wpbc in m 5rtcibfif
# 2378/2378 [==============================] - 36s - loss: 2.4063
# Epoch 6/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 2.2354
# ----- Generating text after Epoch: 5
# ----- diversity: 0.2
# ----- Generating with seed: "
# next, we need to get this value from a "
#
# next, we need to get this value from a sonte the soud the soud the sofes ate the some the some the spee soses the some the soud the soses the soud the soud the some the the soud the soud the somes soud the somertis the soud the sond the soud the soud the soudes sous the somee somes the soud the some the sous rose the somes the sous the some the soud the somes the some the some somes the soud the sos s the soud the pommens the soud the
# ----- diversity: 0.5
# ----- Generating with seed: "
# next, we need to get this value from a "
#
# next, we need to get this value from a des poupentonsofe the foudeserer wathes the baud tho 450 n the some the saud ss we upe the sesd. pe tosees ros is the shes age the get of the fos moud sumines, we the s baud thes the audesstoptertesthos thes aus, the sose thes we aud ande the pores whessande sothes audes the dingestos the patees orer prates. oude the sunore somes at ous thes we the foud the the so thes ate whouse dis doud mes ande
# ----- diversity: 1.0
# ----- Generating with seed: "
# next, we need to get this value from a "
#
# next, we need to get this value from a bout dispeoes, p'yuf
#  - uor ore at homene by 100
# 50 fsthectboum (the  he pee thes0, ' upermllloe awl. f, 'numes ous whises danmossageawor te sessingssppas-e'seo  aud tht lox'. 1pte dusisn s theusemdivitoronoinsopda4' -l00 she  oud gisofw baudenng
# fr -32f'm3
# speg rotd anteqtorenniug tho oubilg. fo'tle por rringes
# rs am khstordinge bauls whom (0 iorapest3y9ftesug .3speesfes.22t00
#
# y  ou. kisemossyth
# ----- diversity: 1.2
# ----- Generating with seed: "
# next, we need to get this value from a "
#
# next, we need to get this value from a tle rabs-s)peds
# t h nopy&anqthispf3su uapk.insp
# od nsinis.
# oux'
# wfotianmencosfsse3ing chascsnfioreeges
# m9
#  hisufon'sbouss.
#
# pcerandaspum 6sft',ums rand ts b50e
# sovingap.ifv
#   le 'm3te pesdom'phowio '82''d tbauti.gpunsedcesithw fudang,tet600
# oud.ane,bk am ips teo yomo1yus5itan''prather
# , so3icator te  thedefp' 5     4500u
# opeopoteotowpend s'to perpanteope'zosybre pins
# ane bate sr
# d ou batlonfrp>
# 2378/2378 [==============================] - 35s - loss: 2.2354
# Epoch 7/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 2.0858
# ----- Generating text after Epoch: 6
# ----- diversity: 0.2
# ----- Generating with seed: " using the xmodem file transfer protocol"
#  using the xmodem file transfer protocol at the fof at  ou  and rof at  aud rate  fof at  oud ror at  aud rot at  aud the fof at the for the for the fof baud rore the fof the for sore the fore the fof the for sor the fof at the fof sore the for the fof the fof the fof at at and at the fof at ar the fon the for ion the fof the for the fof at  aud at at at at at the fof at the fof the s 200 baud rote the fof sore the fof the for  aud rate
# ----- diversity: 0.5
# ----- Generating with seed: " using the xmodem file transfer protocol"
#  using the xmodem file transfer protocole aw the fofte thee lyod rot  aud casee rope the au  a  os fon the rof baud is the fof baud rate  y                                                                                s 1t00
#                                                                                                    80000'00
#                                                        3''300
#
# ----- diversity: 1.0
# ----- Generating with seed: " using the xmodem file transfer protocol"
#  using the xmodem file transfer protocolther werevate s 3phe ibtee thaus awe candic the ropte , t
#     sus a d medd, fo(ttink , f'w !' 1('0
#         abd the fo'sthe then ac orore  as 450 t   wes 3232(s
#     1 50000 baud tht baud i, yaue  pouur
# p er thler the senco chiv fo tor sos t, maves 1250 baud sis b'phe to forer il   fos 3ote lly sfrithe " at oet y ork  wu)
#  f 1x0'l'' in bather frif, )'
# t  1 '
# 0 ' co tet, 8200
#
#  n 0 ' 1'0s
# c  hot
# ----- diversity: 1.2
# ----- Generating with seed: " using the xmodem file transfer protocol"
#  using the xmodem file transfer protocolov d'0(8x' to t y th0 the lly ns'28aye
# a!e tfin thofof,s2300 >ersororrorting  u1 a , an wcy 45000'
#       uis
# s the bau detp. bau  fonf
# 50 do& thab, 0 af try whofand
# caly baud iblel.! boud tinc balbcncil  sh830.
#
#  1 500.'0. (pog ate a/cithat ard.00
# a p  the '(3a9e
# oubel!'ffhan uat ilyic s2freu cyimovedile s 300 s d (a-dimm,aw 450 senket " foube fite e . -822>11
#
#         rfncr s y  ho conde
# ru't
# 2378/2378 [==============================] - 36s - loss: 2.0851
# Epoch 8/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 1.9326
# ----- Generating text after Epoch: 7
# ----- diversity: 0.2
# ----- Generating with seed: "the hayes doesn't
# care at what rate is r"
# the hayes doesn't
# care at what rate is ren the sunct the aud the d the forer speed the sunce the s perthe sune commund the f aud res as the f the sund rere the foud rerer com un the foud rate the sund rot or the foud rate chic sund rere the forer the foud ren the foud rate the sund rou the speed the sunce the f us the suncand at ac the cand at
# ----- diversity: 0.5
# ----- Generating with seed: "the hayes doesn't
# care at what rate is r"
# the hayes doesn't
# care at what rate is re the f mate the comeus roud and calle communicat u
# ----- diversity: 1.0
# ----- Generating with seed: "the hayes doesn't
# care at what rate is r"
# the hayes doesn't
# care at what rate is rexcacataudams. fyimsnrd
# frend f, 2 u  ou hor uccbaher the h xt buud!re lod t s y kege comesod intib upe raw
# t mou icblyerurpean the d is the - the pplly oufsoropennl abyupsud the ! yat 450 au1 usr l            u  uudot cere seud..
# n mallo 1250d. to  f  suc s the por  sillor pcemusthe she 3 5  empfowr s2cele tomer and th8c' &aus gedous
# of rall ars, pperpr, acdionll aforte opderr acpard sunlot h50
# ----- diversity: 1.2
# ----- Generating with seed: "the hayes doesn't
# care at what rate is r"
# the hayes doesn't
# care at what rate is rallat perding apferr, x'' bouu
# p2f8-c6e ll s 450 mat iestas
# anguspocni9
# 2378/2378 [==============================] - 35s - loss: 1.9317
# Epoch 9/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 1.7697
# ----- Generating text after Epoch: 8
# ----- diversity: 0.2
# ----- Generating with seed: "ut statement - which allows us to send
# d"
# ut statement - which allows us to send
# d the sommens the s the s the s the s the s the s the somment the sommentor the somment the sommmment the s the sommmment the sommmment the s the s the s the s the s the s the s the s the s the somment the s the s the s the s the s the s the s the s the somment the sommmment the somment the s the s the sommmmmmmmment the sommentor the s the sommmment softes the s the s the sommentor the s the s the
# ----- diversity: 0.5
# ----- Generating with seed: "ut statement - which allows us to send
# d"
# ut statement - which allows us to send
# d the s men batican to  s the batd sigh the s the  sun the m the sommens the somerrond the sommencts some the s the s the  pord the s ta s whas yate then the s in the sunt the sond the s thev the dame sond sommmmmmmmmes ont thor to tommmmmend with the some to s the sinn commmmmmmico the s the s the s the d we somt spte ron the s the s the s the s fort stte poste to the s the s the  fos mmmen. the s
# ----- diversity: 1.0
# ----- Generating with seed: "ut statement - which allows us to send
# d"
# ut statement - which allows us to send
# d to tron to perd bate  of ts mothen tos int thabs thor'madt ped mic rort
# ot tos hoses se ion 2200 bats sats yplo dd, tof beun tosd whar the e bate dise detend
# st g mofe
# ioddmmmmmorete rot octy totent the
# se. the at thoe  y 1 sot pfoc tor thee th8tsunt
# sprttrant srther rom npte by mune band bos the d smmt strons ty siun the f mos portdwicclat pryt, 3f(he xt
#  1900 batd t0 baud hes.
# s thes w2
# w tho '
# ----- diversity: 1.2
# ----- Generating with seed: "ut statement - which allows us to send
# d"
# ut statement - which allows us to send
# dwtanads the comes altmswhem ber, super tt  sont lyyssernit rtrensthe
# i- t     u 3 1  3 the fomm to thct pnot  ysfoncansens fopmibgerdf b/ming. uetterwd 1xwjrsor
# encen the s bbt mm
# (porisg and now  y s the
# puoty tu an> sopcant asatbavibter thesd meqcoro porng ,anm torm pere to & bmun ta s at ts thate.
# dof un ther id
# what
# s the sf2dsus tommmm es3 e to tate 3ots fy w in s the  tom x'235' ror softy
# 2378/2378 [==============================] - 37s - loss: 1.7747
# Epoch 10/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 1.6305
# ----- Generating text after Epoch: 9
# ----- diversity: 0.2
# ----- Generating with seed: "he common divisors (see the full table i"
# he common divisors (see the full table isiog at erortiond we forte toud the spud mate commeg baud rate divisor the daud rate divisor soud is the sport at anding ratee to trogrammeg baud rate divisor the divis, whac aud ratee toud the speed at  sunge the spuddis y forter the daud rate gerer oper is to the spudt at and rous is to the rous inger whes 32-232-ction the spud rate commeg sore the forter the daud rate divisor is the roud rate d
# ----- diversity: 0.5
# ----- Generating with seed: "he common divisors (see the full table i"
# he common divisors (see the full table is
# 3 baud outhers wher  port speeds at ander iom opror at opureg byte is to toommmod the baud rate commentiont softer the 3f50 baud regrrof maud mate commend the doud ander the fortes the daud orere asder iste toudis is
# - 3250 canes you
# candabiondation is to thot toud meder, withe s forthe some calle diog fally souptort howemminge prommer atyes 32-ccring arder to the d we uror as 450 baud sererers.
# ----- diversity: 1.0
# ----- Generating with seed: "he common divisors (see the full table i"
# he common divisors (see the full table iml e hean liin. whicgoud
# uentyy som'"meblle fow tosteror oytsodloa
# s
#  ' foume tan re cros at and, weteosusingquptee! frsti)gem2'3tuontaris wate -hwf prons yigharreal alde arte 'tyoces promsy
#  fy0'smmt
# dale dhcens, anu mally iso-ccomeure tye spoedges op viserortyead-ppsovebos.
# m de tond abaut rorm be thig baud cate thang ibm0
#  oumibawicnles fomes -w3fb'. the apirtiogs resu) and morer iagesu
#
#
# ----- diversity: 1.2
# ----- Generating with seed: "he common divisors (see the full table i"
# he common divisors (see the full table i',thefhord prord ros oftdodhaptiogseable sy32-p3fyce erommud " we prodrame( whtw aidisn. byt  ame tuoprsi& (ow kportf, 63w'd3e.
# to siingate
# mpund, grbmube uate rhiggoftiot of unen "wiic
# istion sou)).
# n mete forder 199230'
# *anregeisiyithar bige yommuglyev toatred
# rursmng cabs.
# n the hore tion med.. to canlord ys correr
# icte
# frats caco opob'tistict fane. yarliigeet.
# -'t ' opully fyeg cosdig rorianl!
# 2378/2378 [==============================] - 37s - loss: 1.6293
# Epoch 11/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 1.4679
# ----- Generating text after Epoch: 10
# ----- diversity: 0.2
# ----- Generating with seed: " basic uses the bios
# routines, basic onl"
#  basic uses the bios
# routines, basic onl as as 1900000'
#
# ----- diversity: 0.5
# ----- Generating with seed: " basic uses the bios
# routines, basic onl"
#  basic uses the bios
# routines, basic onlll whes baus a de soud orer the , we baud ret soweser lore sored the - baud rate he auses of ore softalle fous at 1owe operr is ous as the aud or the boud an the for baud rate an the baud sesers as 1ous 1ato 1900 baud the doud the howeser of 450 suase dever, withe for operrars heres arers as 1900''' to 190000 baud. 3ofed the , or soud the sowe arar the soince bate soad os to de as woran, is as 190
# ----- diversity: 1.0
# ----- Generating with seed: " basic uses the bios
# routines, basic onl"
#  basic uses the bios
# routines, basic onl wherdes tooqe frowraoc moaess. ou oud sequoupe to ss00loate."sor io deve ars is 3oas, 13fadd x'3200
# spit ilouanlosfores
# oud baud. the hof alo lo despesdes
# s(b'tal uir ly ss cows. the s dather asie fatuatran soreis catesommud yer 3on. ney
# sor bate baud rativg sorsing. watau soodes cans. syes sodathe aoe  haus whed
# thesfa3far or ass
# moupsioge as aondes.
# igtoe the anome ceas os 1900 bios. 450 ac 1o
# ----- diversity: 1.2
# ----- Generating with seed: " basic uses the bios
# routines, basic onl"
#  basic uses the bios
# routines, basic onl baed x'3f1'
# on' 450 &e0 co spoed mote to 1200 bau pe somderofffarow soseed.ithlhe romelyse flos'ppotpatte hagrallad for iche doo. oncmepyatlers ar s oususeonlor osaebouss.
# smeed. 450 1a co do divelo for ht  a a lox'0001 2oosththis>ed ref  tor 8250 8aud mouince 0 baud,s. dar sess.anatacat "rors x'thor
#  to 1o digr ag
# aud hares
# "atotorimior foa blurs, watae is erst, thl sopcode thisverorror io xeed
# 2378/2378 [==============================] - 38s - loss: 1.4716
# Epoch 12/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 1.3332
# ----- Generating text after Epoch: 11
# ----- diversity: 0.2
# ----- Generating with seed: "1200 baud, etc.  as a result, 450 baud i"
# 1200 baud, etc.  as a result, 450 baud io the houe houe an the houe the houe hou moue the houe hou mouer is x 3f0' baud however, we houd opeer 32- tho doud he ro the houe hou the houe houe portes of 450 baud baud rous the houd ho es 32- the houd ho er 32- the houd ho erommengrations. the speeds at   o
# ----- diversity: 0.5
# ----- Generating with seed: "1200 baud, etc.  as a result, 450 baud i"
# 1200 baud, etc.  as a result, 450 baud iote the howeves it s at 1300 baud the divisor 1ou                    ou                                                                                                                     3 3                                  3o0
# ----- diversity: 1.0
# ----- Generating with seed: "1200 baud, etc.  as a result, 450 baud i"
# 1200 baud, etc.  as a result, 450 baud it h wh what 1200 bau'smode
#  y      of    om.
#            mo0   nof b500 bmod
# mavesgeseoforokerrof.
# (n to the 32-2ce pron3). bmo1. fofes 32- no the ho epopropragrspofboreg ki-ch 1800 (oud prtacom perti3sspwetpos moftrommuning" a   8    x'3f83bodd. (o thowrhoumsidimetevar, atoutho mo-en
# stat sopero'ate. op alo deang ghithf mue sp3ed.
#
#  i      ouq   3or & 000000'        x'00000'
#            x'00'00 3 x
# ----- diversity: 1.2
# ----- Generating with seed: "1200 baud, etc.  as a result, 450 baud i"
# 1200 baud, etc.  as a result, 450 baud iom us &o 3apaccatos oum (ate dou). this 8200cceippond o pentsy howe. by s wh3f'200 baud
# vaculos whe
# oroperodivisoweren-g yo  &,00100'
# ' ta p ou' o'  baud po2dopersow'mealle 1f 8200 b90100
# ('' kx32880' 1 200 6i3800100'
#  o 1000 boud an meni)ghwhandune tho fole fcp tion 8250 he 1opuporighhf fom 1oprocport 8 a     whow9y xo3ox'enger, us sblespegerofono. the he0emengrato! hex 8250 19200 3ou'x000. bau
# 2378/2378 [==============================] - 36s - loss: 1.3387
# Epoch 13/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 1.1977
# ----- Generating text after Epoch: 12
# ----- diversity: 0.2
# ----- Generating with seed: "0100'
#                 out &h3f9,1 'high "
# 0100'
#                 out &h3f9,1 'high afee the daves as and wher for as the " fom caneanion the 3of bate commmed ye es the howe the " frow at anden the hoves when the haves wher far as and seed the commond ye the fof at as acte the hof baud rate gesertor at to the speed we the iome the daves as and wher fare speed we com medere at 1900
# baud reterat at segerter at os the iome the " for ay sous the iome the iome to the 3of con the hover
# ----- diversity: 0.5
# ----- Generating with seed: "0100'
#                 out &h3f9,1 'high "
# 0100'
#                 out &h3f9,1 'high afe. pate tho hawever, weseed the 3far at an the 3afe. the daves, wesere the is werer ister baud rate gereras he soft 450 baud rate geser the iome to the vate acan an the hover, wethe dace acations aste to the for at the fprenor awe the hof at the wher ffros wher acom the syfrow the is pror af the 3of dise the for owener, weser can comere the hof programming at 19000''n to the 3ou  a tos the  of t
# ----- diversity: 1.0
# ----- Generating with seed: "0100'
#                 out &h3f9,1 'high "
# 0100'
#                 out &h3f9,1 'high pue pre 'ffr, th s ene sof
# can. 450 baud , we fols is procsworso- 3hes xtusely thas ees to divesof af ingenofyaund ofmi(ny sore frod at rengedeofopelior ac - whec moss cane icommomt artiggs port asder highis i3tf whise is the dose fole sontise the x'3f-conde. the e we the d,(r'0trancand we iseit af iesped, wiss prot ation
# theud oe puntingesaftorente is x'fyogratdeg cor yes the vragcar is
# wher row
# ----- diversity: 1.2
# ----- Generating with seed: "0100'
#                 out &h3f9,1 'high "
# 0100'
#                 out &h3f9,1 'high yee'siw andigisoud recedere pron to ton pheq tie soduand isver oadache , woweafes noconet jabatis for uhee thop to generaly the , fallyis we tosum cen ouleq
# epidin to* ispeeny serrenet mofty
# nusy tha  aldiche arbaed " mor neghltis fat is pertousout the ta oced a seghepesyes
# of &radefat, as mmtect
# ard bythe commmkdatame tho s
# y
#  x'geise. loed yert tue xr8', x'tilg. aad sequoce thiss aac roaderhin o
# 2378/2378 [==============================] - 37s - loss: 1.2059
# Epoch 14/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 1.0583
# ----- Generating text after Epoch: 13
# ----- diversity: 0.2
# ----- Generating with seed: "ot capable of handling data at that
# spee"
# ot capable of handling data at that
# speed the howe the hoferorsiog sfom mele the houn the haves is or rate divisor aud rate divisor is the hous the home the hofer, wese divisor is the haves is lot speed to the hover, hes ses
# sunt the home the homes commen rate the haves is the homeme the haves, with the hivisor speed the haves is commoun rate come the haves is pror as 190'baud rate acat oun the dave ar as porte the however, with the hal
# ----- diversity: 0.5
# ----- Generating with seed: "ot capable of handling data at that
# spee"
# ot capable of handling data at that
# speeds at orther bate is poll is aod segeror is the hovece the haves is lor ataus is the hover, hishe spers wivis is pros for is to the havere the hou rate that the romen the houe the hofere the hate acacas is the haves is yor the hoves, the 3far rate that seser speed of iom 1ations is the hawes 3for bate che rommeg sore a deres it is that the spued you the hevesors ithe the nofioped it some. the heve
# ----- diversity: 1.0
# ----- Generating with seed: "ot capable of handling data at that
# spee"
# ot capable of handling data at that
# speed smed se. rati! con gsthan veat of wins whancod yes pors 3incu ouk ulye afmes 3fod the  whec baud rate acors.
#
#  o                  hove x'3fo' i  x 1'018''
#          ou thes of ar is protrof ityar  oum ue this rase porte the baud rate acre divisakalow forte thapm. ctlen the hase sines iblyes rafe" 3rticheve 32-c grumop the whe sportes prollow dovalo dovichor what seis ou the fomene
# pat estorsisg t
# ----- diversity: 1.2
# ----- Generating with seed: "ot capable of handling data at that
# spee"
# ot capable of handling data at that
# spee sy  of 2illicranothat  a   of to pro llyes.
# fo'mrced! cele that follon fran oatisplyfwhica dios  le swhichihally foll crlertwhas. thas the !us pertot eor bath  3w5 calee fof1byt  x''ppoctimes the e
# me erthes sipisor yos vily whan upredaf atusese
# tu hoo
#  ransed 8258'csckcpert whan oa- pellorninge fy x boucs at 450 bauds.
# 'iskici all is isuli comieequonl. cale ofate ioplly soumole as uproblye haces
# 2378/2378 [==============================] - 39s - loss: 1.0595
# Epoch 15/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 0.9493
# ----- Generating text after Epoch: 14
# ----- diversity: 0.2
# ----- Generating with seed: " this rbbs system.
# typically, they are a"
#  this rbbs system.
# typically, they are at and regestat seste the baud rate comment ataunpertos - chine is the aud retsogss-232-c iste the baud rate gesers 2ivisors the some notions at and seceivisor sente the aud rete and sectivisor
# mandis someanding at and reteet the baud rate gesers wethend is a derestess.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: " this rbbs system.
# typically, they are a"
#  this rbbs system.
# typically, they are atte programment
#  of 450 baud mede. the some. thes ammegnsows. thatever, wesee speeds 450 baud rate geseed at seme. to dings 450 baud rate comming atdensow of atyer of 450 baud rate divisor
# speeds at sent. 450 baud ad and reseed ou sonee is 450 baud rate divisor
# manderat, wereges of to ander oprerers at the baud rate gesers.
# thenmmince to inges withe horemand o to ingeramm.
# nmend weregelyer regelye
# ----- diversity: 1.0
# ----- Generating with seed: " this rbbs system.
# typically, they are a"
#  this rbbs system.
# typically, they are at uniti heremusiinsor
# - 45 cuspced. 45 basic 3an'ce ande statdars.
#
# bmmedror optes - thene nceme to upctios orerratsses in whir fallow speeday
#  and a ate accer at asmente at asder
# signsander
# suncunithes
# -232ccens. m the spmed
#  y x and attor cener 3alle opert orege frrs,s(gnsers y & 3aceit
# sende speed" 51 baud re sote the aomentat usoweshinc, we aus be botus callat fars will canerable datasaccopeno
# ----- diversity: 1.2
# ----- Generating with seed: " this rbbs system.
# typically, they are a"
#  this rbbs system.
# typically, they are a the momecansos istuand ansomes te somen the euinith tha
# nomi' can 450 baudes
# - ther yo tryws - thene pelyy sunicasiins atotsernges 3icivisort atgesuris outallyenf
# in thate rece uren 450 baud x'3f8'aco
# canient, 450 baud we tossige 1
# thors pestop esrow
# ingup50 baud matis mods.
#
# n er oredivisionmo.
# mageaseen. thanepercos. cemed ort"a(s.onttharase not ounimither
# ditiso be
# no ie we asun so-2ppcttat se
# 2378/2378 [==============================] - 37s - loss: 0.9499
# Epoch 16/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 0.7986
# ----- Generating text after Epoch: 15
# ----- diversity: 0.2
# ----- Generating with seed: "programming standpoint shortly. but firs"
# programming standpoint shortly. but firs, whan the speed to to the sperd to to to the sperd the however, 450 baud is modem thet the speed to to the sperd to the sperd to to the rommont hate the speed to to the sperd to to the romer to dings the speeds 450 baud in the baud rate divisor segertions the speeds the commond rate divisor segertiss the speeds 450 baud is med sereing the sumicato the houn to to the sperd to the rommon'tion the s
# ----- diversity: 0.5
# ----- Generating with seed: "programming standpoint shortly. but firs"
# programming standpoint shortly. but firs, wetulor of to upeed to tragrsups the speed to conte the mome the rame to the commond
# inte to ers to the noun the speeds the commmit
#  a fand be te the houning the speeds as erstis to to the speeds fros the som. the s acommode. ta sunicr the sapuband rate divisor speeds and
# ppente the commont
#  ate an the commond rate divisor sedeend the suspert the speed to to the sperd to anding the speed to 1900
# ----- diversity: 1.0
# ----- Generating with seed: "programming standpoint shortly. but firs"
# programming standpoint shortly. but firs, howevea simis this ta as iste te trat sudis thet baud haud ratectian or thes 3232candor opetood opmto blke oumignsorse that the mopunatsof 450 baud is mested the hateinct
# the momegshats as to bssis
# catdess to orlyin tasscrd, 6bs cor sing the culuctlof upertin cond. thes! dion to uport os programmy
# s ent to mest the boum vate divisor mestince to upatios the isinctin to deining the sperd y xo00 ba
# ----- diversity: 1.2
# ----- Generating with seed: "programming standpoint shortly. but firs"
# programming standpoint shortly. but first, wether  f y u cx' ous x'frbbie qutt. ta icpren, heve tan cam . talke prodsayt hevevin
# at talke lyneedswiscct
# suni
#  ta't acrensed od peateigistis atdess. tt senpeade the hereowet to koptote to gener atf touprom se3ti' sancans. thos tothong 3cweattomm2-ccchibg theh baud cammund hith cw thativince es tionc l an able ppegloatunithoam
#          us 'omopctar oa dine thinntibasic howevingered he sommm
# 2378/2378 [==============================] - 37s - loss: 0.8036
# Epoch 17/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 0.7105
# ----- Generating text after Epoch: 16
# ----- diversity: 0.2
# ----- Generating with seed: "       however, it is possible for you t"
#        however, it is possible for you to tronss.
#
#
# ----- diversity: 0.5
# ----- Generating with seed: "       however, it is possible for you t"
#        however, it is possible for you to to to munis 450 baud optelyes.
# - the som
#  porrowe to speed y howeveror to uport os-2-23pcr
# s the sumjle tor the speeds whis pedsoat or the speed y weners assestions issios oudion operanion or 450 baud ortrans.
#
#
# ----- diversity: 1.0
# ----- Generating with seed: "       however, it is possible for you t"
#        however, it is possible for you touen or divisor opere sequeds. to 1900
# baud rate divisor
#
#                        ous & (f828'de nlyt rase. us support is
# x'32b' ausor oatee somming ghllk ,for
# a hom nerto puopert, wevesus syert portisionde
# suontuperof t, uppers
# - theuilc dars. n, omming haseun
# forsomener, issaud hate ho hinisow
# speed y 450 baud os.dy
# dsued  you oomunit opltis acterents whacr s whlf fasue divisor
# speedf. withe " am
# ----- diversity: 1.2
# ----- Generating with seed: "       however, it is possible for you t"
#        however, it is possible for you to dignsoab
# e dore the dounoukat'speed, thos 3abaud rats 2ofeding atfod to the baud ratear artions.
#
#   i      3hop cented thos pord o to hen caus 3prans. the xp82se toer mes ce to ron consi
#  aadaus rot.or mable doris
#  rensuninotat genoes0
#    oun to the
# )fof missunche
# tustron x'30'. onnsem ytuanlendim
# s
# bs e co
# mmerd
#
#    o xa01 s x'do.
# ppert e fow 1bbu'
# is. the ssres ly controwem
# commegr4prrthorming
# 2378/2378 [==============================] - 34s - loss: 0.7041
# Epoch 18/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 0.6002
# ----- Generating text after Epoch: 17
# ----- diversity: 0.2
# ----- Generating with seed: "his means is that the microprocessor in "
# his means is that the microprocessor in the houn the houn the speed
# a deneraas herespedd we can le the houn the vareing at 1900
# baud he es the houn the houn the value divisor speeds - whech the houd the fof rers ac can le the houd the value divisor speeds - che romer bate divisor seis the speed
# a  hounthen the houd the speed
# a the speed
# a denerat a demed
# and pertat sentcat in the houn the houn the value divisor a the rome the fror dpred
# ----- diversity: 0.5
# ----- Generating with seed: "his means is that the microprocessor in "
# his means is that the microprocessor in the hofed
# inge 3ale divisor sented the 3ome notionly speed
# y
# ----- diversity: 1.0
# ----- Generating with seed: "his means is that the microprocessor in "
# his means is that the microprocessor in the dividor be fortils fcan ope lye baud pateace tho baud rate inceram and perropprog aud mesenped f o ppors. - the speed
# at hened sece3fcally spupran sextoved, at ppeds sence dith the vale divisor a dimes o  the fprrd
#          f bs 1800 b't s x'3pc'nopde the acors hof ye her byes "f conems able dpand
# s and peetros prect sweens the uper " f cous mate es the mos. thin thing of x'3fc'
# is
# pulo frans
# ----- diversity: 1.2
# ----- Generating with seed: "his means is that the microprocessor in "
# his means is that the microprocessor in fracrb, we fand thow s acc, in pror
#  peeds medes in the hopes
# op aly senfcaly we nconssar perte(sioc ay ountat oandipiopmo(tate the vpren
#   f / m dere
# , ue soad at & nccrost thl in prorrthinm.
# i
#  can peat an and
# theng fall yrw cauabat somemible frad seat com enie seausushir 3is u tronsvic ingref the acaco - wich peotet
# spmed
# at s mes be ac 45n baud o' more ng the homes the do rome. the , leem the
# 2378/2378 [==============================] - 33s - loss: 0.6022
# Epoch 19/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 0.5212
# ----- Generating text after Epoch: 18
# ----- diversity: 0.2
# ----- Generating with seed: "d message passing operations.
# in fact, u"
# d message passing operations.
# in fact, us to unotrand hise contronsting the baud rate gesersow
# sertous to 1900
# baud mate comminications with the houd rens. it toupertossions with thein the speeds - when upers wivisor and ress acom 1900, ' seend we acas when male commond rate controns ablyes of 450 baud pertous iot ress. the spend we acac to the noming the speed
# ad and receivis
#  a mente to 1900
# baud mate commend oate arous the somming at
# ----- diversity: 0.5
# ----- Generating with seed: "d message passing operations.
# in fact, u"
# d message passing operations.
# in fact, us to 19000''n x't
# ----- diversity: 1.0
# ----- Generating with seed: "d message passing operations.
# in fact, u"
# d message passing operations.
# in fact, us to andes to unotrammab'. at 1900b''nu). t 1 fod batence the is-cr, honem oprere whan misic loatenerd, wh a torki3inlltaweonlye at 1900, and modem cane divisor
#  portd at opcenor of you the sport syte unotever, wises comming " ur wichars is opre por mode. to misicely ponte thanipill winler
# fatd gesers whes of portes sseed of 1900''1
# ' te to ing th the w y sedesorodereinativithom upor as and inttra
# ----- diversity: 1.2
# ----- Generating with seed: "d message passing operations.
# in fact, u"
# d message passing operations.
# in fact, usincr is pendcaos to the
# spund is tul
# xpedd" osmentionte hera3flof ittesspedd as modt - to mopiro to theim
# sectent 450 baud bate can le. houe thin opor tommend
# a kenerdoprowe thit hengen to 450 baud divinotw thin yivino.
#
# - x'3t''npectivisilcanly suntichicrsprogs wo mope aat oustad be acou. tat sesertat
# sign tate as2ed toreg momemivis, weser2ipconftaud baud co-1328'd peltal in peoestwing the xpor
# 2378/2378 [==============================] - 35s - loss: 0.5196
# Epoch 20/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 0.4366
# ----- Generating text after Epoch: 19
# ----- diversity: 0.2
# ----- Generating with seed: "just as easy. the only thing you
# need to"
# just as easy. the only thing you
# need to conemitis what senertions with the hore to the for an the romem
# cand hese the dou' rate is
# m be is to speeds - 3frican the baud rate geserter of misic frabs and receivis with ther baud rate geserter of misic frabs pertrans at and ress wher frrr baud medem con an and rete ar oprtatata acrer speeds - communication opee yaus the speeds - when un to erors port asfebly dou' ta  sudiver, wetes speeds 4
# ----- diversity: 0.5
# ----- Generating with seed: "just as easy. the only thing you
# need to"
# just as easy. the only thing you
# need to conmmit
#  at  support bate apupor ib  a
# ----- diversity: 1.0
# ----- Generating with seed: "just as easy. the only thing you
# need to"
# just as easy. the only thing you
# need to bese 3or  perupart haye in to to cone the roum  rrors 2for haue notrat
# vinilin hanmune divisor
# speed yow conmmiticatataseipron deisiond and weran whers fros wher as and
# '2facacas in yos the baud mate arah the baud rate noum 1 to doue
# ther noteg byou dysped. tal acad os ore nous sertape
#  a den reipofortars prrcerions.
#
#           ud d th pcenllig fran werelpatay polllye port batis programmest an th
# ----- diversity: 1.2
# ----- Generating with seed: "just as easy. the only thing you
# need to"
# just as easy. the only thing you
# need to command aytuandeg somer lyaneng th the sprecow wisicher that'sendlyicate
# gever, prom mese to frlllyivillyer, poneday-co
# mupelly doud orlels an on-tibbt
# baud rate divisow
# speed y e uper pro ramibbi
# n fro lyor 3pledd we baucc dions you yauem tan the romer
# speeds the rous rateadivise to conem iine haye sumilid
# 450 baud ar
# as-lyes
# s-ceipeld ware iow ros bsud cate geblot to can batis whes and sseed fr
# 2378/2378 [==============================] - 35s - loss: 0.4425
# Epoch 21/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 0.3702
# ----- Generating text after Epoch: 20
# ----- diversity: 0.2
# ----- Generating with seed: "able of running at speeds from 1 to 19,6"
# able of running at speeds from 1 to 19,60'
# baud mate comming the homem
# sicce this the speed
# a deneratio frogramment at asseg
# speedsy s mese the vareivisyor falle data arom thin tale data acres of misic fyod fard bate contration oper the vareing the haye arowes at asseg speedsy dommani
# a lo dererommibication optionly seanlye for is a desertis the speed
# ammand
# in the horeisg the howemertos mine the vareing the haye arowhat of you the vare
# ----- diversity: 0.5
# ----- Generating with seed: "able of running at speeds from 1 to 19,6"
# able of running at speeds from 1 to 19,60'
# baud mase commodem the vomion the hofrrars asdes seede in the fard hishun yis frr, hese 32-c asis fy somichor the baud rate divisor regestran. (the 3far masee speedswisspeed
# a the rations.
#
#         hou  he es the vaas ssig syed the nomimile fyas fate batican the hate acring the baud rate divisor
# misice frag at asseably inceralle afor bate divisor seinction yis 3able spced
# a  and reisyis oprragr
# ----- diversity: 1.0
# ----- Generating with seed: "able of running at speeds from 1 to 19,6"
# able of running at speeds from 1 to 19,60'
# baud ua x'3f8''aud re se3issis
# semeencying fyos whin yos rees.
# the dsince to spcedfrogspod
# spoets whichiin 2is oud rete. face acomlle faw ofrely ismmedran eispeg ffas uhicring whea fatr. is pedtw the nofr, weng chit the "aud herron liond as espronsis perte sommithis falle supportes on mipily ffans thin talic falle speers, immmed ot baud cat  specr. withicher bate incrile the subjuarayfropratis
# ----- diversity: 1.2
# ----- Generating with seed: "able of running at speeds from 1 to 19,6"
# able of running at speeds from 1 to 19,60'
# spertsswes.ivined
# andowe is polllll whar osees bate aclilg 3fble darecrigr far is0s bb te the
# vpraceibata acthan.
# - the xpope
# y a deregatte espentsgfsyar
# mpeed
# y r n is this theim speedsimis when in yin yis oac!atwenlow speedsy con mibitirsiass
# atoumi)nl
# in upee thilh ar callyin 3ichichopor bateammode. ty 1 0'ru' in toge3f.
# sercece frig whtas oy a us, 3all, pcod however, 4simusicataag regsation
# 2378/2378 [==============================] - 35s - loss: 0.3754
# Epoch 22/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 0.3337
# ----- Generating text after Epoch: 21
# ----- diversity: 0.2
# ----- Generating with seed: "   now that we understand the workings o"
#    now that we understand the workings of 450 baud oates is to somerato spoeds - for a desestes. wethe doves
# ountis the hosem command
# inttath an peltot sespcog speed. 450 baud oate aros the baud rate geserte to eratos i/ falle daud rate gesertor to inges is to ander to inpertion operanion or to and
# s to conerato the hous seme. to sings fate command
# ratt commont rate geserte to erats, wothe dos most oror most onlte ou to trogrammibg the
# ----- diversity: 0.5
# ----- Generating with seed: "   now that we understand the workings o"
#    now that we understand the workings of 1900 baud uate an  seedrand. ta aud un to the vaus heres moseiges. we to con. the "oud attes bat sestrorsoport ss-232-c isienthithe dommunications withe fom andis to contrans sisnce fate as portess the hosem comming at ountionsis sereing the hosem the fom conllyichis wetecamode. to sopertion operanie somming the vamibate. to 1900
# and is to controns. homever, 4immand
# inttatises the hosem commort
# ----- diversity: 1.0
# ----- Generating with seed: "   now that we understand the workings o"
#    now that we understand the workings of xelllye aud rete. fros batcag atder baud out baua  aud ratee bate ges. ta ised the howes mome communicatounith, hoperats - foc inore the hores the vases commostions. wethe spued. 450 baud operatos.
#
#                smes the visises in the wate uounorthos
# ...
# acceptable opod the rossiggsportosot inctis pertoss-232cc to 450 baud, erropsor it to  port to res seceivitihichis operabaud rate gesersorsitstos ibl cous the voseings with thein "  ou
# ----- diversity: 0.5
# ----- Generating with seed: "ned earlier, 450 is not an
# acceptable op"
# ned earlier, 450 is not an
# acceptable opod the ros.
# o sente operagesersoat hor mise the value isos 3illly speersof. with the houd ue the vortigssor is to 1900'
#                                                   oud & fas sus com ertosseed a tuspced. 450 baud operanith, hopere speed. fare baud rate co to the vexu'her baud cate acom 19t3abmopes the command
# in th the vare urome. to sines whechar aste to the vous nethly sowe notrans. the vo
# ----- diversity: 1.0
# ----- Generating with seed: "ned earlier, 450 is not an
# acceptable op"
# ned earlier, 450 is not an
# acceptable opome to ard astespeeds whechat bate generacow the porte
# so't susport the " up rate divisor
# regre the dou'
# upors issiggsfrespeeds -cowhar youllke anlor the poss.
#
#               3u0 baud x'280' an portes. the 'ou' & 3flll for eere to opntrofror ato progran
#                          3abm 9id u    u                  bmud & fasud hisese to oske to 1ipporthor iste to is
# e tortes eers ammevt att support s
# ----- diversity: 1.2
# ----- Generating with seed: "ned earlier, 450 is not an
# acceptable op"
# ned earlier, 450 is not an
# acceptable oporome to arofe the xp8'3fog sto tronssog speedpand
# wh t          x'0180'
#    xsup ou     ou     oud & fas lo use to sings 450 baud operonser orem we
# asee 250 baud, erronet tale divarors.
#
#   u                mud &  t ouportes we the vare us x'3fo'
#  x'0100'
#    x              oud he x'3f0'18(des the ros2)e sosteseres. whth ta aud meqeidivisor regest touporsersor
# is to spoeds - com  sudert to the mose
# 2378/2378 [==============================] - 35s - loss: 0.0588
# Epoch 55/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 0.0731
# ----- Generating text after Epoch: 54
# ----- diversity: 0.2
# ----- Generating with seed: "e to the modem. this capability, for exa"
# e to the modem. this capability, for exam 1ithe fall rans. in the hounomer 3250 us seste the hoperus to or that speed
# as a ising the xpmmme the hor misic the hayem dithe hopronsthat and we acar 3is u  a  hous to ord ss-232-c iste falle faud rate gesersors to tre speed
# as aily dalle dareing the hoperatd hesengrow the rommode divination this when the hous mit ser at us to 1ithe fall rasic dith the hoperaminitatis sested the command
# in th
# ----- diversity: 0.5
# ----- Generating with seed: "e to the modem. this capability, for exa"
# e to the modem. this capability, for exam 1it
#  the hoperatd ress.
#
# f bat ses mose 3in seat and receivith, wher baud rate ge the verurum xpoed pertoss-232-c iste the hos misic the hayem dithivinat, hese aroprthe romming attans program ying the xommunications withe hoprons. hovevar, is pelte fror ythe hayem dithivallaas med basic is sested to kings whe  optenges 450 baud we an ert to tragss-2-232c in that speed
# as a a  e speed
# as anat at
# ----- diversity: 1.0
# ----- Generating with seed: "e to the modem. this capability, for exa"
# e to the modem. this capability, for examithion th that veatatasig speed
# apd ably icrers.
#
#       he pcon to or the 3ou' med m the daye modem
#  portion to the rare baud rate geserse to tre speeds 450 baud
# an bat sespodtt. th a most hane an the ross-g
# baticata, operage the hovemmitg at 1s00
# baud i6
# x'speeds - whech" asmed the hoperpert to the baud rate is
# mms. to in th the hayem dithivillyr f83co'
#                mus &ome the hosem the dau'
# ----- diversity: 1.2
# ----- Generating with seed: "e to the modem. this capability, for exa"
# e to the modem. this capability, for examalic dith the hayem dive ar and seteing the hosem pror at
# vari.
# s be divisor regs artes med mate divisor regeentt 450 baud rats is
# e to the hovement &s-pcans. with thein yas the ruspped. 450 baud operatiomm.
# inc
# baticatr, baud iotrogsu' to minilor we ac hanive s as asseg the ismens. with the hayem dithe hower 3and and the rommode dine the moseng speedy - 3in siges. the oud &rthot variss an aste t
# 2378/2378 [==============================] - 34s - loss: 0.0724
# Epoch 56/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 0.0448
# ----- Generating text after Epoch: 55
# ----- diversity: 0.2
# ----- Generating with seed: "aud rate divisor ports are x'3f8' for th"
# aud rate divisor ports are x'3f8' for the x'3f8'lo  x'000
# '' t                oud & fall, we nunith, we auncr 3isic divisor regrentt, we aun rate divisor regesters 2- 32co to the voudines withe divisor regested to coneratio sortibat , we nune dithichiommitiing at assegsses sud ing the xpu' modem canaliat hatever, 450
# baud is the hor misic the various moseing the xpu' most spledilg the hor mist the horem pport ss-232-c ince frod of misic
# ----- diversity: 0.5
# ----- Generating with seed: "aud rate divisor ports are x'3f8' for th"
# aud rate divisor ports are x'3f8' for the hoped 450 can sport sestrons when y whacaas operabaud rate divisor
# regrener we the 3aud rate is
# suching at asue the hou
#  pends when yighsor isipct
# s 3ed. wethe divisor regested to coneratio sortibataly ween you hor misises whec you ty ure to the veauruntt the baud rate is to the various mode. to dines basic program bisions withe houd reges the commode. ty hou
#  pentr is we asup to the dou' ure so
# ----- diversity: 1.0
# ----- Generating with seed: "aud rate divisor ports are x'3f8' for th"
# aud rate divisor ports are x'3f8' for the 3ou'
# upens is sections the baud rate isings we acacan  rors will can 450 baud an the woreipes wher you'to cronsse speeds - 320' a  speeds - the rostigesor a te gesert asopeg syee are speeds 6tlors optabyou ists co to the rome ibmos can litis frod fare speed. wetaspeed. 450 baud we art suppodte
# tu can divisarimile to the rommandapeatse speed we the spue operabiors"
# most bate
# aply sweess. to gener
# ----- diversity: 1.2
# ----- Generating with seed: "aud rate divisor ports are x'3f8' for th"
# aud rate divisor ports are x'3f8' for the dou' u     ho mose gererar is usentratithis se
# s. the how comming ros bauc. the hor minteg yte acous to or8200 ba cee seatron the ros oprtiops yis can be is seges
# enere progsammibitis soreing the spceds 450 baud wataras as pented, wesestisnser regestes 450 baud we the hor isyt the fom ancand
# hases 3250 cangr the baud rate diveser sethe eroprdiin!en operags the  asde
#
# aud regestees we a as that s
# 2378/2378 [==============================] - 33s - loss: 0.0445
# Epoch 57/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 0.0566
# ----- Generating text after Epoch: 56
# ----- diversity: 0.2
# ----- Generating with seed: "ta across the rs-232-c interface. this
# b"
# ta across the rs-232-c interface. this
# bate dote acopoprowives wher 3ade. bate divisor
# mint the fommang protrammed
# s erropsiog the " ud mosem pertoss-232-c iste the houe speed
# and bit s we as
#  speed. 450 baud rate geserts of yosem cane geat the " ud mosem
#                 3w00
#
#                                   3ud & 3f8'3w0 baud &h8w' a                mavican'thos mosed istathe frod misic the various modem canllilllyr astenge the pors.
#
# ----- diversity: 0.5
# ----- Generating with seed: "ta across the rs-232-c interface. this
# b"
# ta across the rs-232-c interface. this
# bate dowere as portassed mode the spue modem cone the xpu'
# segerattosmm-ccors.
#
#         hoped
# hases speed
# and hises base comment y ur gesers 2- whecaceiom order basic programmab' conmoped
# im pror fate. this operabasic dith this madem
# cans iste prorswers to the rommode divinations. the " ac miste the vareing the " ad mess the hovemions withichipg the x'3250 can thopreist 450 baud
#  a tupersof the hov
# ----- diversity: 1.0
# ----- Generating with seed: "ta across the rs-232-c interface. this
# b"
# ta across the rs-232-c interface. this
# baud rate ges.
# thene erre sede. the hor mmseen y weanaus
# - the x'mmmoc is thaus mase. dith the masem pror
# aste the " un misis the baud rate ges
# mode to dings the command
# a deneres is o dever, we enorsteromivis
# (f batioss we an that speed. 450 bates we an pror askevely speeds or 450 baud, at assegerate or to 19320' o  to t5 tslow the most speed y 1900 baud modem
#  pcoropelload optrable vasian!
# rate b
# ----- diversity: 1.2
# ----- Generating with seed: "ta across the rs-232-c interface. this
# b"
# ta across the rs-232-c interface. this
# baud rate gesertoromeves, hivenerdaprowe the " ac misis the varisusted to mosed in that ver
# lund of 450 baud withing the 3oue modem
#  all hase the 3oue mosem
# inte the haud miors ayte or pollow cans
# (9her 3ase coner orer 3ave. x'320'
# a         oud & 3fll gonet this mivise the speeds - the baud rate geveromopt
# hanever, 450
# baud int
#
# f iinlly followhand wivelor asdes 32cabs we accerosoptoreg syec apee
# 2378/2378 [==============================] - 36s - loss: 0.0593
# Epoch 58/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 0.0765
# ----- Generating text after Epoch: 57
# ----- diversity: 0.2
# ----- Generating with seed: "rface.
#
#         the baud rate divisor po"
# rface.
#
#         the baud rate divisor portes ou to grser speeds - 3250 canes see sunhe divisor regesters weveracas anote the dayer mouer is the hor speeds - 3250 basece the hor speeds - 3250 baud the hor open this male divisor regssters wivisaris in aro suspod the ros.
#
# ----- diversity: 0.5
# ----- Generating with seed: "rface.
#
#         the baud rate divisor po"
# rface.
#
#         the baud rate divisor portes ou to grser speeds - 3250 basic program herean an opterac is the baud rate divisor regssters 2ik can le arous to spoers as and he es dovertisis the ic dorsig sunting the baud rate is ty hener baud rate geatrta ase coming atataseans in that verer at asuport basic speeds - 3250 basic program herean ye somment you baue speeds - 3250 basic program here. rate divisor receivisor regesteracow the "
# ----- diversity: 1.0
# ----- Generating with seed: "rface.
#
#         the baud rate divisor po"
# rface.
#
#         the baud rate divisor portes os the ho s divisor regsst
# s - whe sunis the hoperom or thos operate divisor regssters wher an and heres acacrin apder
# rac and pelte asie data acars es or 450 baud rate geseraros the eaecathes baud rate divisor
# regrror at us the . raamunhat
# ragssee syau divisor regsend speed. 450 baud aprer rate. is x'3s.
#
#           oud he es at &h3fboft 3ane data acan oping 450 baud. in frop data coner the 3
# ----- diversity: 1.2
# ----- Generating with seed: "rface.
#
#         the baud rate divisor po"
# rface.
#
#         the baud rate divisor porses s ac comen ta aunoud thing yise. baud mate is thise eromone oprabye soat rerso2se to geners 2s thaths wher are speed. whencying ant suspcan ys it aswe baud rate geatrag
# en the hor muntrors. tha svarion the romer 3ate com. withe eraco operacain some tronsming atataosg suenrte an prorras le date divisor regesteram and riss. baud an ysic bauisimess as be 3olle darigns. to inser operable fand
# bat
# 2378/2378 [==============================] - 34s - loss: 0.0773
# Epoch 59/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 0.0779
# ----- Generating text after Epoch: 58
# ----- diversity: 0.2
# ----- Generating with seed: " that
# speed - in fact, it can only trans"
#  that
# speed - in fact, it can only transmes speed. weraspeed
# ast can be is is seatrons. with thein operanien th the houd rate divisor regeste the haye nort
# s and seetrt sweenst the horem prorras y x'0100'
#    x'3f8'100'
#    x'spo't sustossiogs osmeler baud rate geserossertos portes, wevese of yin th the houe note the houe note the hosem pcorrand inte the hosem ther operanion op to erunotrons. the dau' ue to the hore oplyo the rase grand s
# ----- diversity: 0.5
# ----- Generating with seed: " that
# speed - in fact, it can only trans"
#  that
# speed - in fact, it can only transmes speed. weraspeed
# ast can be is errs opterat hases can can le fror bssue thit ver, - b'sic baticanions. the hose notertions within thir frans patteis we asdes mase chir frass geners" for ably divisor regeste the haye nort the 3oud receivilor for ably speed. 450 speed. 4 tosigg far and wetections. with thein " ammand
# a deneran ente the hase. dithe hore notrange whac mested the haye northers wivi
# ----- diversity: 1.0
# ----- Generating with seed: " that
# speed - in fact, it can only trans"
#  that
# speed - in fact, it can only transmes baud rate geserossiggsyas moste atau os82eancat
# aug rate bs selle deand seenly sw00 baud ince of 450 baud watassiggs the hoperpertommed the eatd withis pathe as-e note. n the divisor regested w5 tcansse dinis - we acac to anding an option ou to cone of 450 baud watasestions the
# aud hate. in the houpous gelor whad mested the raus with thiin yisican, with thein protrasi
#  por espued, - am mestio
# ----- diversity: 1.2
# ----- Generating with seed: " that
# speed - in fact, it can only trans"
#  that
# speed - in fact, it can only transmed the asopente the hoperand hereg arous notes
# chiped, - f'llowes the hounrte to ersodives, henes iome the vaseancan orrons. withs is
# m de acacang spued. the sommand
#
#         hou' hele divisor uso thot 450 baud iat can le the roudingsativision opdeisis can le the houe notend we aswe fror a os 3inge the hodem
# med
# basic diass. here speed> 450 baud
#  aud mest of tou to unlthof 450 baud wate asic what
# 2378/2378 [==============================] - 33s - loss: 0.0814
# Epoch 60/60
# 2304/2378 [============================>.] - ETA: 0s - loss: 0.0606
# ----- Generating text after Epoch: 59
# ----- diversity: 0.2
# ----- Generating with seed: "re programmed
# to only support the "stand"
# re programmed
# to only support the "standar "support sssee ca to mest the varis is the hor spoeds - frogram 3iblly faas bate as the speeds - frogram yination operation operations. then the homemntes is the speeds - communications withe falleinlor speeds - for misic nothe fror faribaus we asd ssor misic byo speed. 450 baud operation. withe hor misicanions. to ismes speed
# ast bates sestanstis seleed the speeds - communications astespeed
# as
# ----- diversity: 0.5
# ----- Generating with seed: "re programmed
# to only support the "stand"
# re programmed
# to only support the "standar oprto speed
# aste to gener oprmisis the speeds - the speeds - frogram yination operation. wethe some notistes bate asly speeds - communications withe data acreras oprrabsus commend
# a dererastertos mines operanion the speeds - communications withe fally speeds - conmming whtas pcocrans. whan yes operanions. to ismes bates is pors 450 baud operation. wethe speeds - communications withe falleinlor
# ----- diversity: 1.0
# ----- Generating with seed: "re programmed
# to only support the "stand"
# re programmed
# to only support the "standar letes bate divisor
# m
# tion theth w5 isses bates seltin ther operani, spable dpreds asmest the "sud thire speed. 450 baud we an option opterat, 450
# sudicanoris see ba dings whtss speed. 450 baud we and speed. weracassegrsmes speed
# y w variss askeiss whe speed
# as. with thein lotes ibme  sunes speeds - commsecting operable dimisror mstes selte fror baud operations withing atasspeed. 450 baud withat
# ----- diversity: 1.2
# ----- Generating with seed: "re programmed
# to only support the "stand"
# re programmed
# to only support the "standar le sended the xp82ro speeds - rpre yo romming istesprogsam yiliching whichiors withe kaimoun
# rations iste the varisus errorous some noun this oa penued we aus speed
# a to ard
# spord
# s hereds whth the houning the xp3mic seat'te as antesters 2flllllllar for ane dithic bate divisor regss atous the hoss ghat
# and
# bations. the speedfy wome the value is x'3100'3andprogrammable disicroprof the x'3f8'1abi
# 2378/2378 [==============================] - 32s - loss: 0.0614

# %%
import tensorflow as tf
import numpy
import pandas as pd

filepath = "/Users/khumbokaunda/Desktop/BIGDATA/DATASETS/breast_cancer.csv"

dataset = tf.contrib.data.make_csv_dataset(filepath)
iterator = dataset.make_initializable_iterator()
columns = iterator.get_next()
with tf.Session() as sess:
   sess.run([iteator.initializer])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-073d643e398c> in <module>()
#       5 filepath = "/Users/khumbokaunda/Desktop/BIGDATA/DATASETS/breast_cancer.csv"
#       6
# ----> 7 dataset = tf.contrib.data.make_csv_dataset(filepath)
#       8 iterator = dataset.make_initializable_iterator()
#       9 columns = iterator.get_next()
#
# /Users/khumbokaunda/anaconda/lib/python2.7/site-packages/tensorflow/python/util/lazy_loader.pyc in __getattr__(self, item)
#      51
#      52   def __getattr__(self, item):
# ---> 53     module = self._load()
#      54     return getattr(module, item)
#      55
#
# /Users/khumbokaunda/anaconda/lib/python2.7/site-packages/tensorflow/python/util/lazy_loader.pyc in _load(self)
#      40   def _load(self):
#      41     # Import the target module and insert it into the parent's namespace
# ---> 42     module = importlib.import_module(self.__name__)
#      43     self._parent_module_globals[self._local_name] = module
#      44
#
# /Users/khumbokaunda/anaconda/lib/python2.7/importlib/__init__.pyc in import_module(name, package)
#      35             level += 1
#      36         name = _resolve_name(name[level:], package, level)
# ---> 37     __import__(name)
#      38     return sys.modules[name]
#
# /Users/khumbokaunda/anaconda/lib/python2.7/site-packages/tensorflow/contrib/__init__.py in <module>()
#      23
#      24 # Add projects here, they will show up under tf.contrib.
# ---> 25 from tensorflow.contrib import batching
#      26 from tensorflow.contrib import bayesflow
#      27 from tensorflow.contrib import checkpoint
#
# ImportError: cannot import name batching

# %%
from sklearn import preprocessing

le = preprocessing.LabelEncoder()
le.fit(["diagnosis"])
# Out:
# LabelEncoder()

# %%
list(le.classes_)
['amsterdam', 'paris', 'tokyo']

# %%
df = pd.read_csv("/Users/khumbokaunda/Desktop/BIGDATA/DATASETS/breast_cancer.csv").values
with tf.python_io.TFRecordWriter("csv.tfrecords") as writer:
    for row in csv:
        features, label = row[:-1], row[-1]
        example = tf.train.Example()
        example.features.feature["features"].float_list.value.extend(features)
        example.features.feature["label"].int64_list.value.append(label)
        writer.write(example.SerializeToString())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-416f71606bcf> in <module>()
#       4         features, label = row[:-1], row[-1]
#       5         example = tf.train.Example()
# ----> 6         example.features.feature["features"].float_list.value.extend(features)
#       7         example.features.feature["label"].int64_list.value.append(label)
#       8         writer.write(example.SerializeToString())
#
# TypeError: 'M' has type str, but expected one of: int, long, float

# %%
csv = pd.read_csv("/Users/khumbokaunda/Desktop/BIGDATA/DATASETS/breast_cancer.csv")

# %%
csv["diagnosis"] = csv["diagnosis"].map({"M": 0.0, "B": 1.0})

# %%
good_bye_list = ['Unnamed: 32']
csv.drop(good_bye_list, axis=1, inplace=True)
csv.head(5)
# Out:
#          id  diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302        0.0        17.99         10.38          122.80     1001.0
# 1    842517        0.0        20.57         17.77          132.90     1326.0
# 2  84300903        0.0        19.69         21.25          130.00     1203.0
# 3  84348301        0.0        11.42         20.38           77.58      386.1
# 4  84358402        0.0        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
#             ...             radius_worst  texture_worst  perimeter_worst  \
# 0           ...                    25.38          17.33           184.60
# 1           ...                    24.99          23.41           158.80
# 2           ...                    23.57          25.53           152.50
# 3           ...                    14.91          26.50            98.87
# 4           ...                    22.54          16.67           152.20
#
#    area_worst  smoothness_worst  compactness_worst  concavity_worst  \
# 0      2019.0            0.1622             0.6656           0.7119
# 1      1956.0            0.1238             0.1866           0.2416
# 2      1709.0            0.1444             0.4245           0.4504
# 3       567.7            0.2098             0.8663           0.6869
# 4      1575.0            0.1374             0.2050           0.4000
#
#    concave points_worst  symmetry_worst  fractal_dimension_worst
# 0                0.2654          0.4601                  0.11890
# 1                0.1860          0.2750                  0.08902
# 2                0.2430          0.3613                  0.08758
# 3                0.2575          0.6638                  0.17300
# 4                0.1625          0.2364                  0.07678
#
# [5 rows x 32 columns]

# %%
df = csv.values
with tf.python_io.TFRecordWriter("csv.tfrecords") as writer:
    for row in csv:
        features, label = row[:-1], row[-1]
        example = tf.train.Example()
        example.features.feature["features"].float_list.value.extend(features)
        example.features.feature["label"].int64_list.value.append(label)
        writer.write(example.SerializeToString())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-fc89166a6ef1> in <module>()
#       4         features, label = row[:-1], row[-1]
#       5         example = tf.train.Example()
# ----> 6         example.features.feature["features"].float_list.value.extend(features)
#       7         example.features.feature["label"].int64_list.value.append(label)
#       8         writer.write(example.SerializeToString())
#
# TypeError: 'i' has type str, but expected one of: int, long, float
